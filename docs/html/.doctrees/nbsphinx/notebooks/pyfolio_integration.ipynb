# %% [markdown]
# # Pyfolio Integration

# %% [markdown]
# Alphalens can simulate the performance of a portfolio where the factor values are use to weight stocks. Once the portfolio is built, it can be analyzed by Pyfolio. For details on how this portfolio is built see:
# - alphalens.performance.factor_returns
# - alphalens.performance.cumulative_returns
# - alphalens.performance.create_pyfolio_input

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import alphalens
import pyfolio
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %% [markdown]
# First load some stocks data

# %%
tickers = [ 'ACN', 'ATVI', 'ADBE', 'AMD', 'AKAM', 'ADS', 'GOOGL', 'GOOG', 'APH', 'ADI', 'ANSS', 'AAPL',
'AVGO', 'CA', 'CDNS', 'CSCO', 'CTXS', 'CTSH', 'GLW', 'CSRA', 'DXC', 'EBAY', 'EA', 'FFIV', 'FB',
'FLIR', 'IT', 'GPN', 'HRS', 'HPE', 'HPQ', 'INTC', 'IBM', 'INTU', 'JNPR', 'KLAC', 'LRCX', 'MA', 'MCHP',
'MSFT', 'MSI', 'NTAP', 'NFLX', 'NVDA', 'ORCL', 'PAYX', 'PYPL', 'QRVO', 'QCOM', 'RHT', 'CRM', 'STX',
'AMG', 'AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'AJG', 'AIZ', 'BAC', 'BK', 'BBT', 'BRK.B', 'BLK', 'HRB',
'BHF', 'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG', 'CME', 'CMA', 'DFS', 'ETFC', 'RE', 'FITB', 'BEN',
'GS', 'HIG', 'HBAN', 'ICE', 'IVZ', 'JPM', 'KEY', 'LUK', 'LNC', 'L', 'MTB', 'MMC', 'MET', 'MCO', 'MS',
'NDAQ', 'NAVI', 'NTRS', 'PBCT', 'PNC', 'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'STT', 'STI', 'SYF', 'TROW',
'ABT', 'ABBV', 'AET', 'A', 'ALXN', 'ALGN', 'AGN', 'ABC', 'AMGN', 'ANTM', 'BCR', 'BAX', 'BDX', 'BIIB', 'BSX',
'BMY', 'CAH', 'CELG', 'CNC', 'CERN', 'CI', 'COO', 'DHR', 'DVA', 'XRAY', 'EW', 'EVHC', 'ESRX', 'GILD', 'HCA',
'HSIC', 'HOLX', 'HUM', 'IDXX', 'ILMN', 'INCY', 'ISRG', 'IQV', 'JNJ', 'LH', 'LLY', 'MCK', 'MDT', 'MRK', 'MTD',
'MYL', 'PDCO', 'PKI', 'PRGO', 'PFE', 'DGX', 'REGN', 'RMD', 'SYK', 'TMO', 'UNH', 'UHS', 'VAR', 'VRTX', 'WAT',
'MMM', 'AYI', 'ALK', 'ALLE', 'AAL', 'AME', 'AOS', 'ARNC', 'BA', 'CHRW', 'CAT', 'CTAS', 'CSX', 'CMI', 'DE',
'DAL', 'DOV', 'ETN', 'EMR', 'EFX', 'EXPD', 'FAST', 'FDX', 'FLS', 'FLR', 'FTV', 'FBHS', 'GD', 'GE', 'GWW',
'HON', 'INFO', 'ITW', 'IR', 'JEC', 'JBHT', 'JCI', 'KSU', 'LLL', 'LMT', 'MAS', 'NLSN', 'NSC', 'NOC', 'PCAR',
'PH', 'PNR', 'PWR', 'RTN', 'RSG', 'RHI', 'ROK', 'COL', 'ROP', 'LUV', 'SRCL', 'TXT', 'TDG', 'UNP', 'UAL',
'AES', 'LNT', 'AEE', 'AEP', 'AWK', 'CNP', 'CMS', 'ED', 'D', 'DTE', 'DUK', 'EIX', 'ETR', 'ES', 'EXC']

# %% [markdown]
# ### YFinance Download

# %%
import yfinance as yf

df = yf.download(tickers, start='2015-01-01',  end='2017-01-01')
df.index = pd.to_datetime(df.index, utc=True)
# Out:
# [                       1%                       ]  3 of 247 completed$JEC: possibly delisted; no timezone found
# [                       1%                       ]  3 of 247 completed$ANTM: possibly delisted; no timezone found
# [***                    6%                       ]  15 of 247 completed$BHF: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# [*******               15%                       ]  37 of 247 completed$CTXS: possibly delisted; no timezone found
# [**********            20%                       ]  50 of 247 completed$ARNC: possibly delisted; no timezone found
# [**********            21%                       ]  51 of 247 completed$SRCL: possibly delisted; no timezone found
# [**********            21%                       ]  52 of 247 completed$ANSS: possibly delisted; no timezone found
# [***********           23%                       ]  57 of 247 completed$FLIR: possibly delisted; no timezone found
# [***********           23%                       ]  58 of 247 completed$MYL: possibly delisted; no timezone found
# [************          24%                       ]  59 of 247 completed$PBCT: possibly delisted; no timezone found
# [************          24%                       ]  59 of 247 completed$RHT: possibly delisted; no timezone found
# [**************        29%                       ]  72 of 247 completed$STI: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# [**************        30%                       ]  75 of 247 completed$CMA: possibly delisted; no timezone found
# [****************      33%                       ]  81 of 247 completed$FBHS: possibly delisted; no timezone found
# [****************      33%                       ]  82 of 247 completed$BK: possibly delisted; no timezone found
# [****************      33%                       ]  82 of 247 completed$ALXN: possibly delisted; no timezone found
# [*******************   39%                       ]  96 of 247 completed$ABC: possibly delisted; no timezone found
# [*******************   40%                       ]  100 of 247 completed$BRK.B: possibly delisted; no timezone found
# [********************  41%                       ]  101 of 247 completed$HOLX: possibly delisted; no timezone found
# [********************* 43%                       ]  105 of 247 completed$HRS: possibly delisted; no timezone found
# [********************* 43%                       ]  107 of 247 completed$DFS: possibly delisted; no timezone found
# [**********************45%                       ]  111 of 247 completed$PDCO: possibly delisted; no timezone found
# [**********************49%                       ]  121 of 247 completed$PKI: possibly delisted; no timezone found
# [**********************50%                       ]  123 of 247 completed$FB: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# [**********************54%*                      ]  133 of 247 completed$ATVI: possibly delisted; no timezone found
# [**********************54%*                      ]  134 of 247 completed$JNPR: possibly delisted; no timezone found
# [**********************55%*                      ]  135 of 247 completed$RTN: possibly delisted; no timezone found
# [**********************55%*                      ]  136 of 247 completed$INFO: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# [**********************56%**                     ]  138 of 247 completed$BCR: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01)
# [**********************58%***                    ]  143 of 247 completed$KSU: possibly delisted; no timezone found
# [**********************59%***                    ]  145 of 247 completed$CA: possibly delisted; no timezone found
# [**********************60%****                   ]  148 of 247 completed$CELG: possibly delisted; no timezone found
# [**********************63%*****                  ]  155 of 247 completed$NLSN: possibly delisted; no timezone found
# [**********************63%*****                  ]  156 of 247 completed$ADS: possibly delisted; no timezone found
# [**********************70%*********              ]  173 of 247 completed$LUK: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01)
# [**********************72%**********             ]  179 of 247 completed$RE: possibly delisted; no timezone found
# [**********************74%***********            ]  183 of 247 completed$MMC: possibly delisted; no timezone found
# [**********************83%***************        ]  205 of 247 completed$ETFC: possibly delisted; no timezone found
# [**********************87%*****************      ]  215 of 247 completed$CERN: possibly delisted; no timezone found
# [**********************87%*****************      ]  216 of 247 completed$VAR: possibly delisted; no timezone found
# [**********************91%*******************    ]  226 of 247 completed$IR: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# [**********************96%*********************  ]  236 of 247 completed$AGN: possibly delisted; no timezone found
# [**********************99%***********************]  244 of 247 completed$LLL: possibly delisted; no timezone found
# [*********************100%***********************]  247 of 247 completed
#
# 43 Failed downloads:
# ['JEC', 'ANTM', 'CTXS', 'ARNC', 'SRCL', 'ANSS', 'FLIR', 'MYL', 'PBCT', 'RHT', 'CMA', 'FBHS', 'BK', 'ALXN', 'ABC', 'BRK.B', 'HOLX', 'HRS', 'DFS', 'PDCO', 'PKI', 'ATVI', 'JNPR', 'RTN', 'KSU', 'CA', 'CELG', 'NLSN', 'ADS', 'RE', 'MMC', 'ETFC', 'CERN', 'VAR', 'AGN', 'LLL']: possibly delisted; no timezone found
# ['BHF', 'STI', 'FB', 'INFO', 'IR']: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01) (Yahoo error = "Data doesn't exist for startDate = 1420088400, endDate = 1483246800")
# ['BCR', 'LUK']: possibly delisted; no price data found  (1d 2015-01-01 -> 2017-01-01)

# %% [markdown]
# ### Data Formatting

# %%
df = df.stack()
df.index.names = ['date', 'asset']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 101882 entries, (Timestamp('2015-01-02 00:00:00+0000', tz='UTC'), 'A') to (Timestamp('2016-12-30 00:00:00+0000', tz='UTC'), 'XRAY')
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Adj Close  0 non-null       float64
#  1   Close      101882 non-null  float64
#  2   High       101882 non-null  float64
#  3   Low        101882 non-null  float64
#  4   Open       101882 non-null  float64
#  5   Volume     101882 non-null  float64
# dtypes: float64(6)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Compute Factor

# %% [markdown]
# We'll compute a simple mean reversion factor looking at recent stocks performance: stocks that performed well in the last 5 days will have high rank and vice versa.

# %%
factor = df.loc[:,'Open'].unstack('asset')
factor = -factor.pct_change(5)
factor = factor.stack()

# %% [markdown]
# The pricing data passed to alphalens should contain the entry price for the assets so it must reflect the next available price after a factor value was observed at a given timestamp. Those prices must not be used in the calculation of the factor values for that time. Always double check to ensure you are not introducing lookahead bias to your study.
#
# The pricing data must also contain the exit price for the assets, for period 1 the price at the next timestamp will be used, for period 2 the price after 2 timestats will be used and so on.
#
# There are no restrinctions/assumptions on the time frequencies a factor should be computed at and neither on the specific time a factor should be traded (trading at the open vs trading at the close vs intraday trading), it is only required that factor and price DataFrames are properly aligned given the rules above.
#
# In our example, before the trading starts every day, we observe yesterday factor values. The price we pass to alphalens is the next available price after that factor observation: the daily open price that will be used as assets entry price. Also, we are not adding additional prices so the assets exit price will be the following days open prices (how many days depends on 'periods' argument). The retuns computed by Alphalens will therefore based on assets open prices.

# %%
pricing = df.loc[:,'Open'].unstack('asset').iloc[1:]

# %% [markdown]
# ## Run Alphalens Analysis

# %% [markdown]
# ### Get Input Data

# %%
factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor,
                                                                   pricing,
                                                                   periods=(1, 3, 5),
                                                                   quantiles=5,
                                                                   bins=None)
# Out:
# Dropped 1.0% entries from factor data: 1.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!

# %% [markdown]
# ### Summary Tear Sheet

# %%
alphalens.tears.create_summary_tear_sheet(factor_data);
# Out:
# Quantiles Statistics
#                       min       max      mean       std  count    count %
# factor_quantile
# 1               -0.750000  0.075580 -0.042620  0.038201  20128  20.158035
# 2               -0.116319  0.094967 -0.014323  0.020766  19876  19.905659
# 3               -0.080440  0.109978 -0.002114  0.019736  19917  19.946721
# 4               -0.048482  0.127588  0.009922  0.020126  19876  19.905659
# 5               -0.028052  0.428571  0.036718  0.033673  20054  20.083925
# Returns Analysis
#                                                   1D     3D     5D
# Ann. alpha                                     0.311  0.141  0.103
# beta                                           0.108  0.048  0.052
# Mean Period Wise Return Top Quantile (bps)     5.391  2.621  2.016
# Mean Period Wise Return Bottom Quantile (bps) -3.376 -1.929 -1.834
# Mean Period Wise Spread (bps)                  8.767  4.546  3.845
# Information Analysis
#                      1D     3D     5D
# IC Mean           0.016  0.012  0.016
# IC Std.           0.180  0.176  0.176
# Risk-Adjusted IC  0.089  0.068  0.093
# t-stat(IC)        1.982  1.502  2.058
# p-value(IC)       0.048  0.134  0.040
# IC Skew           0.051  0.126  0.052
# IC Kurtosis       0.285  0.159  0.273
# Turnover Analysis
#                               1D     3D     5D
# Quantile 1 Mean Turnover   0.348  0.600  0.787
# Quantile 2 Mean Turnover   0.605  0.741  0.799
# Quantile 3 Mean Turnover   0.651  0.761  0.784
# Quantile 4 Mean Turnover   0.604  0.743  0.796
# Quantile 5 Mean Turnover   0.351  0.596  0.781
#                                      1D     3D     5D
# Mean Factor Rank Autocorrelation  0.749  0.358 -0.016

# %% [markdown]
# ## Run Pyfolio Analysis

# %% [markdown]
# ### Get Input Data

# %% [markdown]
# We can see in Alphalens analysis that quantiles 1 and 5 are the most predictive so we'll build a portfolio data using only those quantiles.

# %%
pf_returns, pf_positions, pf_benchmark = \
    alphalens.performance.create_pyfolio_input(factor_data,
                                               period='1D',
                                               capital=100000,
                                               long_short=True,
                                               group_neutral=False,
                                               equal_weight=True,
                                               quantiles=[1,5],
                                               groups=None,
                                               benchmark_period='1D')

# %% [markdown]
# ### Pyfolio Tearsheet

# %% [markdown]
# Now that we have prepared the data we can run Pyfolio functions

# %%
pyfolio.tears.create_full_tear_sheet(pf_returns,
                                     positions=pf_positions,
                                     benchmark_rets=pf_benchmark)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-01-09</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-12-22</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>34</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.102%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>24.699%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.167%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.53</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-4.043%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.39</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.47</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>1.47</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>19.73</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.62%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.04</td>
#       <td>2016-03-30</td>
#       <td>2016-11-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.52</td>
#       <td>2016-01-04</td>
#       <td>2016-01-19</td>
#       <td>2016-02-01</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.32</td>
#       <td>2015-02-04</td>
#       <td>2015-03-17</td>
#       <td>2015-04-07</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.31</td>
#       <td>2015-09-17</td>
#       <td>2015-09-28</td>
#       <td>2015-10-22</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.05</td>
#       <td>2015-08-18</td>
#       <td>2015-08-21</td>
#       <td>2015-08-24</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.03%</td>
#       <td>-1.39%</td>
#       <td>3.51%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.03%</td>
#       <td>-1.39%</td>
#       <td>3.51%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AAL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AAPL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ADBE</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ADI</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AEE</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AEP</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AES</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AET</th>
#       <td>1.25%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>AAL</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ABT</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ACN</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ADBE</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ADI</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>AEE</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>AEP</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>AES</th>
#       <td>-1.25%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AAL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AAPL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ABT</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ACN</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ADBE</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ADI</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AEE</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AEP</th>
#       <td>1.25%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Subset Performance

# %% [markdown]
# ### Weekday Analysis

# %% [markdown]
# Sometimes it might be useful to analyze subets of your factor data, for example it could be interesting to see the comparison of your factor in different days of the week. Below we'll see how to select and analyze factor data corresponding to Mondays, the positions will be held the for a period of 5 days

# %%
monday_factor_data = factor_data[ factor_data.index.get_level_values('date').weekday == 0 ]

# %%
pf_returns, pf_positions, pf_benchmark = \
    alphalens.performance.create_pyfolio_input(monday_factor_data,
                                               period='5D',
                                               capital=100000,
                                               long_short=True,
                                               group_neutral=False,
                                               equal_weight=True,
                                               quantiles=[1,5],
                                               groups=None,
                                               benchmark_period='1D')

# %% [markdown]
# ### Pyfolio Tearsheet

# %%
pyfolio.tears.create_full_tear_sheet(pf_returns,
                                     positions=pf_positions,
                                     benchmark_rets=pf_benchmark)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-01-12</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-12-19</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>33</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>3.299%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>9.549%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.329%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.433%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.37</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>4.48</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>64.66</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.658%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.15</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.43</td>
#       <td>2015-12-20</td>
#       <td>2016-08-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.49</td>
#       <td>2015-02-08</td>
#       <td>2015-03-30</td>
#       <td>2015-04-27</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.84</td>
#       <td>2015-06-28</td>
#       <td>2015-08-17</td>
#       <td>2015-08-24</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.52</td>
#       <td>2015-10-04</td>
#       <td>2015-10-05</td>
#       <td>2015-10-12</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.44</td>
#       <td>2015-05-17</td>
#       <td>2015-05-18</td>
#       <td>2015-06-15</td>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.10%</td>
#       <td>-0.70%</td>
#       <td>4.57%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-2.10%</td>
#       <td>4.57%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ACN</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AES</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ALGN</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AMD</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AON</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>BDX</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>CFG</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>CSCO</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>DXC</th>
#       <td>1.25%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAL</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>AET</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ALK</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>ALLE</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>BMY</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>BSX</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>CI</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>CME</th>
#       <td>-1.25%</td>
#     </tr>
#     <tr>
#       <th>CNC</th>
#       <td>-1.25%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>asset</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AAPL</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ACN</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AES</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AET</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ALGN</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ALK</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>ALLE</th>
#       <td>1.25%</td>
#     </tr>
#     <tr>
#       <th>AMD</th>
#       <td>1.25%</td>
#     </tr>
#   </tbody>
# </table>
